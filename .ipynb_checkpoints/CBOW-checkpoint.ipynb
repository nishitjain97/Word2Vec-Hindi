# %%
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
import string
import re
import pickle

from __future__ import print_function
from matplotlib import pylab
from matplotlib.font_manager import FontProperties
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %matplotlib inline
hindi_font = FontProperties(fname='Nirmala.ttf')

# %%
def clean_text(sentence, language):
    """
        Input: String, String
        Output: String
        Takes in text as string. Returns text cleaned for NMT purposes.
    """
    if language == None:
        print("Please enter which language.")
        return None
        
    exclude = set(string.punctuation)
    remove_digits = str.maketrans('', '', string.digits)
        
    if language == 'en':
        sentence = sentence.lower()
        sentence = ''.join(ch for ch in sentence if ch not in exclude)
        sentence = sentence.translate(remove_digits)
        sentence = sentence.strip()
        sentence = re.sub(" +", " ", sentence)
        return sentence
    
    elif language == 'hi':
        sentence = sentence.lower()
        sentence = ''.join(ch for ch in sentence if ch not in exclude)

        sent_temp = ''
        for c in sentence:
            if c == ' ':
                sent_temp += c
            elif ord(u'\u0900') <= ord(c) <= ord(u'\u097F'):
                sent_temp += c
        sentence = sent_temp
      
        sentence = re.sub('[a-z]', '', sentence)
        sentence = re.sub('[०१२३४५६७८९।]', '', sentence)
        sentence = sentence.translate(remove_digits)
        sentence = sentence.strip()
        sentence = re.sub(" +", " ", sentence)
        return sentence
    
    elif language == 'ma':
        sentence = sentence.lower()
        sentence = ''.join(ch for ch in sentence if ch not in exclude)
        sentence = re.sub('[a-z]', '', sentence)
        sentence = re.sub('[०१२३४५६७८९।]', '', sentence)
        sentence = sentence.translate(remove_digits)
        sentence = sentence.strip()
        sentence = re.sub(" +", " ", sentence)
        return sentence
    
    else:
        print("Language not found")
        return None

# %%
root = '.'

def read_data(filename, number_of_lines):
    data = ""
    
    with open(os.path.join(root, filename)) as f:
        for i in  range(number_of_lines):
            data += clean_text(tf.compat.as_str(f.readline()).strip(), 'hi')
            
    return data.split(' ')

words = read_data('monolingual.hi', 10000)
print("Data size %d" % len(words))
# Out:
# Data size 256528

# %%
vocabulary_size = int(len(set(words)) // 1.2)

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size-1))
    dictionary = dict()
    
    for word, _ in count:
        dictionary[word] = len(dictionary)
    
    data = list()
    unk_count = 0
    
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0
            unk_count += 1
        data.append(index)
    
    count[0][1] = unk_count
    
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print("Vocabulary size", vocabulary_size)
print("Most common words (+UNK)", count[:5])
print("Sample data", data[:10])
del words
# Out:
# Vocabulary size 20936
# Most common words (+UNK) [['UNK', 4189], ('के', 11901), ('में', 9205), ('की', 7543), ('है', 5234)]
# Sample data [100, 1024, 2, 2797, 1, 488, 10, 11320, 113, 385]

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
    global data_index
    span = 2 * bag_window + 1
    batch = np.ndarray(shape=(batch_size, span-1), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    buffer = collections.deque(maxlen=span)
    
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    
    for i in range(batch_size):
        buffer_list = list(buffer)
        labels[i, 0] = buffer_list.pop(bag_window)
        batch[i] = buffer_list
        
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('Data:', [reverse_dictionary[di] for di in data[:16]])

for bag_window in [1, 2]:
    data_index = 0
    batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
    print("\nwith bag_window = %d:" % (bag_window))
    print(" batch:", [[reverse_dictionary[w] for w in bi] for bi in batch])
    print(" label:", [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# Data: ['भारतीय', 'राजनीति', 'में', 'पिछड़ेपन', 'के', 'विचार', 'का', 'सूत्रीकरण', 'उसे', 'खत्म', 'करने', 'के', 'मकसद', 'से', 'किया', 'गया']
#
# with bag_window = 1:
#  batch: [['भारतीय', 'में'], ['राजनीति', 'पिछड़ेपन'], ['में', 'के'], ['पिछड़ेपन', 'विचार']]
#  label: ['राजनीति', 'में', 'पिछड़ेपन', 'के']
#
# with bag_window = 2:
#  batch: [['भारतीय', 'राजनीति', 'पिछड़ेपन', 'के'], ['राजनीति', 'में', 'के', 'विचार'], ['में', 'पिछड़ेपन', 'विचार', 'का'], ['पिछड़ेपन', 'के', 'का', 'सूत्रीकरण']]
#  label: ['में', 'पिछड़ेपन', 'के', 'विचार']

# %%
batch_size = 128
embedding_size = 128
bag_window = 2
valid_size = 16
valid_window = 100
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size], stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
    
    embeds = tf.nn.embedding_lookup(embeddings, train_dataset)
    loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, 
                                                     inputs=tf.reduce_sum(embeds, 1), labels=train_labels, 
                                                     num_sampled=num_sampled, num_classes=vocabulary_size))
    
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
    
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:1344: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print("Initialized")
    average_loss = 0
    
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, bag_window)
        feed_dict = {train_dataset: batch_data, train_labels: batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            print("Average loss at step %d: %f" % (step, average_loss))
            average_loss = 0
        
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log = "Nearest to %s:" % valid_word
                
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = "%s %s" % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/site-packages/tensorflow/python/util/tf_should_use.py:118: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Average loss at step 0: 7.257196
# Nearest to हुई: करेंगेउन्होंने दयालपुर सेक्शन उधारी ऑलराउंडर बढ़ेगासऊदीअरब दोबजे पी
# Nearest to न: आसीन मुशर्रफ एक्सोडस दौसा थेकालांतर संतोष एचटीएमएल छुटकारापाने
# Nearest to ज्यादा: सर्वसुलभ गईहालांकि ओपेराविनफ्रेशो डेवलेपमेंट ठहरा संपादक कर्मचारियो एलिस
# Nearest to एक: याद हैइसीतरह रन किरकिरी थादूसरा डिपार्चर पुनरुद्धार दोदिन
# Nearest to हुए: उपकरण शेनपर्किन्स झिंगन गिरगांव भंडार सर्टिफिकेट बैठाना सीमा
# Nearest to देने: जोनलेयन आगमन रहेगाबैंक ह लवरंगतर्शुफू साधा थेनेता ड्राइवकरने
# Nearest to इस: आकड़ों लटकाया देवबंदी चाहिएबजट हैन्यूक्लियरप्लांट अनुसन्धान अघोषित गेंदों
# Nearest to और: उम्मीदवारी मेनाएडेल सकेजूलियनअसांज बाएं रहेगाइस थासाइंटिस्ट ज़ाविया बच
# Nearest to जब: गुजर सकेगीइन आलोचना ग्रामीण हथेली सावधानी चाहताउन्होंने मंदिर
# Nearest to के: लपेट दीउधर मौक़ा पिटिशन बिशपसंस्थान गईलेकिन मांगना डेरस्पीगल
# Nearest to वह: सेवन थीमौैजूदा लोकुगे करेंगेसुडान जाएगाफिलहाल देतेसप्ताह सामनेकन्वर्जिसबीपीओ तलालबिनअब्दुल
# Nearest to भारत: टैक्टिस रीयल्टी जिसतरह समझाने डीबी रास्ते करेगीस्वीडन थाउस
# Nearest to अपनी: चारलाख रहाइसके मिलेगीहालांकि तारीफ़ विधान ड्राइवर मुशर्रफ थाआयकर
# Nearest to ये: काराकुल विचित्र बंधन कत्लेआम लियालेकिन अमेरिका फोरब्रेन मुर्दा
# Nearest to करने: सड़को नितिनगडकरी अवसर बॉयलॉजी साजिशकर्ता महत्व बनी हैंजर्मनी
# Nearest to गए: जनसेवाओं एलिसइनवंडरलैंड रखकर बंबई तालिबानपाकिस्तान डी लीमैच वॉर
# Average loss at step 2000: 4.309535
# Average loss at step 4000: 2.978280
# Average loss at step 6000: 2.463110
# Average loss at step 8000: 2.155515
# Average loss at step 10000: 1.941453
# Nearest to हुई: सेक्शन मिले श्रमिक एलबालाजी खेले फायदों कियामुशर्रफ देंआपको
# Nearest to न: गिराआन्दोलनकारी परीक्षणों प्रत्यारोपित ज़रुरत ऐसा अमेरिकीओपन पातीइस लेेकर
# Nearest to ज्यादा: कम मिटा ज़्यादा अधिक हैंब्रिटनी मुठभेड़ कम्पाउंड बिल्डिंगें
# Nearest to एक: काबिजमुअम्मरगद्दाफी हैपेशावर पहली यूनेस्को द्विवेदी पूछने ढहने उठे
# Nearest to हुए: शेनपर्किन्स बैठाना गिरगांव बल्ब सर्टिफिकेट शाहअब्दुल्लाबिनअब्दुलअजीज उपकरण वादक
# Nearest to देने: करने लेने रखने ऑफ़ भविष्ट पर्यवेक्षकों रोकने पड़ेगासोमवार
# Nearest to इस: हैइस उस दोहराया इंडियन मोशन गेंदों मॉस्को एग्रीकल्चर
# Nearest to और: लेकिन तो क्योंकि जबकि सफाया चट्टानों दादाजी जोकि
# Nearest to जब: ग्रामीण चलाता सीरिज़ योग्य गुजर करनीं माधवकुमार रॉबिनहोडेस
# Nearest to के: उनके इसके गुनदीपकुमार ब्रैंडेड स्पैक्ट्रम अंतरिम मुबारक़ डॉयरेक्टरबासेम
# Nearest to वह: वो वे हैंसिंह जाएगाफिलहाल शांतिभूषण स्कोर्पियो हैंसीवीसी खेलेऔर
# Nearest to भारत: हैप्यूजो थेकार पाकिस्तान खोखला डोपिंग समारोहों ड्यूमिनी अरबडॉलर
# Nearest to अपनी: अरुणनेहरू चारलाख पारा काडूना पुणेएक्सप्रेसहाइवे विधान लीना दुआ
# Nearest to ये: यह काराकुल बोले इंग्लिश दारुल इंजीनियर सलमानबशीर पताचला
# Nearest to करने: होने देने पूराकरने करके लौहपुरुष बनाने फ़ायदेमंद वैंगपाओ
# Nearest to गए: जाते जाने रहे सकते जन्में मैपिंग विराटकोहली ग्राफ्ट
# Average loss at step 12000: 1.772180
# Average loss at step 14000: 1.622515
# Average loss at step 16000: 1.503582
# Average loss at step 18000: 1.402564
# Average loss at step 20000: 1.312749
# Nearest to हुई: सेक्शन होती मिले फायदों होगी करवाती कियामुशर्रफ फॉस्फोरिक
# Nearest to न: परीक्षणों विलियमबॉरुकी न्योता दोफरवरी कनफ्यूज लेेकर गएलूट आउटलेट्स
# Nearest to ज्यादा: कम ज़्यादा मुठभेड़ अधिक मिटा ठहरा हैंब्रिटनी बहिष्कार
# Nearest to एक: हैपेशावर काबिजमुअम्मरगद्दाफी द्विवेदी श्रीलंकाई करनीं मुड़ताऔर हैएक यूनेस्को
# Nearest to हुए: बैठाना शेनपर्किन्स गिरगांव धारी हैदक्षिणीसूडान वादक प्रियदर्शनीमट्टू बल्ब
# Nearest to देने: लेने भविष्ट करने मानने पड़ेगासोमवार रखने पूराकरने ऑफ़
# Nearest to इस: हैइस उस दीवाइल्ड इसी पूछो हैजसवंतसिंह दोहराया पताचला
# Nearest to और: क्योंकि तो जबकि लेकिन मॉडिफाइड डिजिटल एवं जिसमें
# Nearest to जब: ग्रामीण चलाता निकोटीन हैवहीं जिनका रहस्यमय मंगलवार यूटिलाइजेशन
# Nearest to के: उनके इसके गुनदीपकुमार फर्राटे मुबारक़ अंतरिम जिसके उसके
# Nearest to वह: वो चोसुनइलबो शांतिभूषण जियोन्यूज उसने वे जिसने स्कोर्पियो
# Nearest to भारत: पाकिस्तान डीटीसी टैक्सस बांह हैआडवाणी राउंड लियासाथ सिक्किम
# Nearest to अपनी: उदारीकरण अरुणनेहरू चारलाख काडूना तेहरान ड्राइवर सिखाने दुआ
# Nearest to ये: यह बोले मशीनें उधार सलमानबशीर पताचला मलिक रहाअगर
# Nearest to करने: होने जोड़ने पूराकरने देने वैंगपाओ बनाने रखने लौहपुरुष
# Nearest to गए: जाते जाने रहे जाएंगे चुके गई ग्राफ्ट जन्में
# Average loss at step 22000: 1.239859
# Average loss at step 24000: 1.157570
# Average loss at step 26000: 1.100591
# Average loss at step 28000: 1.043629
# Average loss at step 30000: 0.989066
# Nearest to हुई: होती सेक्शन मिले करवाती देंआपको फायदों जाताउनकी विसंगतियों
# Nearest to न: न्योता नहीं गएलूट नियत मारसिनमात्कोवस्की लेेकर विलियमबॉरुकी कनफ्यूज
# Nearest to ज्यादा: कम ज़्यादा मुठभेड़ विनोदसरोज अधिक हैंब्रिटनी मढ़ता हलका
# Nearest to एक: यूनेस्को चाहिएभारतीय आईमान एफ किसी द्विवेदी बनानेवाली ढहने
# Nearest to हुए: बैठाना ध्रुव ऐस शाहअब्दुल्लाबिनअब्दुलअजीज बल्ब हुआ प्रियदर्शनीमट्टू गैज़ेटेड
# Nearest to देने: लेने पूराकरने भविष्ट मानने रखने पड़ेगासोमवार आस्था टी
# Nearest to इस: हैइस इसी उस यह उसी इंडियन नाबाद एग्रीकल्चर
# Nearest to और: लेकिन जबकि क्योंकि तो जोकि रहेगाप्रधानमंत्री मॉडिफाइड नैसकॉम
# Nearest to जब: चलाता ग्रामीण रहस्यमय हैवहीं मंगलवार विरोधात्मक यूटिलाइजेशन हैवियतनाम
# Nearest to के: उनके गुनदीपकुमार ब्रैंडेड अंतरिम इसके उसके मुबारक़ करेगीइस
# Nearest to वह: जिसने शांतिभूषण वो हैंसिंह वे उसने एसेसमेंट विज
# Nearest to भारत: राउंड डीटीसी दुनियाभर जीतने दिल काईटी बांह मुकाबलों
# Nearest to अपनी: उदारीकरण आर्तयोमवेलेयेव विधान एसकेभट्टाचार्य होगीडायबिटीज पारा ड्राइवर अरुणनेहरू
# Nearest to ये: यह मलिक मशीनें बोले कैलशियम प्रदानकरने हैंतभी रहाअगर
# Nearest to करने: होने जोड़ने पूराकरने लौहपुरुष बनाने फ़ायदेमंद वैंगपाओ देने
# Nearest to गए: जाने गई जाते जाएंगे जन्में चुके रहे दस्तावेज
# Average loss at step 32000: 0.945799
# Average loss at step 34000: 0.891537
# Average loss at step 36000: 0.861667
# Average loss at step 38000: 0.829267
# Average loss at step 40000: 0.802894
# Nearest to हुई: देंआपको सेक्शन होती गुनगुनाते विसंगतियों फायदों पूरीतरहसे एलबालाजी
# Nearest to न: गएलूट ललितभनोट लेेकर इंटरसेप्ट कनफ्यूज खड़ी विलियमबॉरुकी गिराआन्दोलनकारी
# Nearest to ज्यादा: कम ज़्यादा मुठभेड़ अधिक हलका हैंब्रिटनी यह रहेगाइसी
# Nearest to एक: यूनेस्को द्विवेदी श्रीलंकाई एफ असहमति करनीं चाहिएभारतीय हैपेशावर
# Nearest to हुए: ध्रुव धारी बैठाना ऐस बल्ब बिलक्लिंटन अफ़्रीकी शाहअब्दुल्लाबिनअब्दुलअजीज
# Nearest to देने: भविष्ट मानने पूराकरने आस्था लेने रखने देते हैशायद
# Nearest to इस: हैइस उस इसी किस उसी चाहिएएनएसजी यह सुसमैन
# Nearest to और: जबकि क्योंकि एवं जोकि लेकिन तो दादाजी मॉडिफाइड
# Nearest to जब: रहस्यमय यूटिलाइजेशन मंगलवार हैवहीं चलाता हैवियतनाम सिंधसरकार हार्टअटैक
# Nearest to के: उनके फर्राटे इसके का ब्रैंडेड उसके गुनदीपकुमार सरप्राइजिंग
# Nearest to वह: वो जिसने वे थम शांतिभूषण एसेसमेंट अजमेरजिले मैं
# Nearest to भारत: राउंड दिल सख्त दफ्तर होअतीत जमीनपर नजरिए परिपक्व
# Nearest to अपनी: एसकेभट्टाचार्य उदारीकरण पारा होगीडायबिटीज उनकी आर्तयोमवेलेयेव इंद्रेशकुमार खारिजकर
# Nearest to ये: यह उधार कैलशियम प्रदानकरने रहाअगर बोले काराकुल लैबोरेटरी
# Nearest to करने: होने पूराकरने फ़ायदेमंद रखने वैंगपाओ लौहपुरुष जोड़ने पाने
# Nearest to गए: जाने जाते गई चुके रहे ग्राफ्ट जाएंगे जन्में
# Average loss at step 42000: 0.774489
# Average loss at step 44000: 0.746144
# Average loss at step 46000: 0.723539
# Average loss at step 48000: 0.696424
# Average loss at step 50000: 0.677006
# Nearest to हुई: सेक्शन देंआपको सौंपी गईमगर होती पूरीतरहसे विसंगतियों करवाती
# Nearest to न: कनफ्यूज इंटरसेप्ट गएलूट दानापुर लेेकर खड़ी मधुकांतपाठक गिराआन्दोलनकारी
# Nearest to ज्यादा: ज़्यादा कम अधिक मुठभेड़ हैंब्रिटनी रहेगाइसी हलका बैक्टीरियल
# Nearest to एक: यूनेस्को श्रीलंकाई एफ घराने हालैंड द्विवेदी चुननी हैवजह
# Nearest to हुए: धारी बैठाना याचिका ध्रुव बिलक्लिंटन वादक प्रियदर्शनीमट्टू अफ़्रीकी
# Nearest to देने: भविष्ट पूराकरने मानने दिया हैशायद मनाने आस्था लेने
# Nearest to इस: हैइस उस एग्रीकल्चर इसी यह किस कियानेचरन्यूरोसाइंस थाइस
# Nearest to और: एवं क्योंकि जबकि दादाजी जोकि लेकिन रहेगाप्रधानमंत्री धब्बे
# Nearest to जब: रहस्यमय मंगलवार फर्क चलाता यूटिलाइजेशन हैवियतनाम हार्टअटैक बीएमडब्ल्यू
# Nearest to के: उनके ब्रैंडेड का इसके फर्राटे हैंफर्ज हैइसके हैआप
# Nearest to वह: वो जिसने वे प्रायश्चित हैउन्होंन थम अजमेरजिले धनतेरस
# Nearest to भारत: हैश्रम तयकरने अरबडॉलर होअतीत बांह जमीनपर हैब्रिटिशपुलिस सेतिया
# Nearest to अपनी: उदारीकरण उनकी एसकेभट्टाचार्य होगीडायबिटीज पारा खारिजकर ड्राइवर आर्तयोमवेलेयेव
# Nearest to ये: यह कैलशियम रहेबढ़ती लैबोरेटरी प्रदानकरने बोले शासित वे
# Nearest to करने: होने पूराकरने बनाने जोड़ने वैंगपाओ करके लौहपुरुष रखने
# Nearest to गए: गई जाते जाने जन्में चुके रहे जाएंगे सकतीसरकार
# Average loss at step 52000: 0.658352
# Average loss at step 54000: 0.640921
# Average loss at step 56000: 0.618979
# Average loss at step 58000: 0.602789
# Average loss at step 60000: 0.590147
# Nearest to हुई: देंआपको होती गईमगर पूरीतरहसे सौंपी जाताउनकी विसंगतियों सेक्शन
# Nearest to न: गिराआन्दोलनकारी खड़ी गएलूट चालू ऑनलाइन मधुकांतपाठक कनफ्यूज तिरस्कार
# Nearest to ज्यादा: अधिक ज़्यादा कम डॉसेन रहेगाइसी हैंब्रिटनी वेदर निरंतरता
# Nearest to एक: यूनेस्को असहमति घराने श्रीलंकाई द्विवेदी प्रस्थान ईडनगार्डन्स एफ
# Nearest to हुए: धारी बैठाना ऐस गेम्सविलेज ध्रुव वादक बिलक्लिंटन हुआ
# Nearest to देने: भविष्ट आस्था पूराकरने मानने लेने दिया हैशायद जुटाने
# Nearest to इस: हैइस इसी उस एग्रीकल्चर थाइस चाहिएएनएसजी यह पूछो
# Nearest to और: जबकि क्योंकि लेकिन जोकि एवं दादाजी गोल्डमैनसैक्स अंधाधुंध
# Nearest to जब: यूटिलाइजेशन रहस्यमय मंगलवार फार्मास्युटिकल हार्टअटैक फर्क बीएमडब्ल्यू हैवियतनाम
# Nearest to के: का इसके ब्रैंडेड उनके अंतरिम उसके गुनदीपकुमार हैंउसके
# Nearest to वह: वो मैं जिसने अजमेरजिले धनतेरस शांतिभूषण विज थम
# Nearest to भारत: बांह अरबडॉलर तयकरने समाज सेतिया हैश्रम हैआडवाणी एनएसजी
# Nearest to अपनी: एसकेभट्टाचार्य उदारीकरण पारा होगीडायबिटीज उनकी खारिजकर ड्राइवर सूखा
# Nearest to ये: यह प्रदानकरने वे लैबोरेटरी हलका हैंतभी कैलशियम रहेबढ़ती
# Nearest to करने: होने पूराकरने करके बनाने लौहपुरुष जोड़ने वैंगपाओ फ़ायदेमंद
# Nearest to गए: जाने गई जाते जन्में चुके रहे जाएंगे सकतीसरकार
# Average loss at step 62000: 0.574506
# Average loss at step 64000: 0.560972
# Average loss at step 66000: 0.546718
# Average loss at step 68000: 0.538891
# Average loss at step 70000: 0.527763
# Nearest to हुई: देंआपको पूरीतरहसे होती होगी कियामुशर्रफ गईमगर सौंपी सेक्शन
# Nearest to न: तिरस्कार इंटरसेप्ट संभाली तहसीलदारों वैन्यू चालू खूबसूरत उन्हें
# Nearest to ज्यादा: अधिक ज़्यादा कम रहेगाइसी हैंब्रिटनी डॉसेन शुरूहो नेअभिषेकबच्चन
# Nearest to एक: यूनेस्को घराने असहमति एफ काबिजमुअम्मरगद्दाफी द्विवेदी हैपेशावर श्रीलंकाई
# Nearest to हुए: धारी बैठाना बिलक्लिंटन वादक सदीकउल्लाह गेम्सविलेज टाइकून ऐस
# Nearest to देने: भविष्ट पूराकरने दिया हैशायद लेने टी आस्था मानने
# Nearest to इस: हैइस इसी एग्रीकल्चर उस यह थाइस पहन हैंइस
# Nearest to और: जबकि लेकिन जोकि दादाजी गोल्डमैनसैक्स क्योंकि औरैया शाहअब्दुल्लाह
# Nearest to जब: मंगलवार रहस्यमय फार्मास्युटिकल यूटिलाइजेशन चलाता दोदिन हैनया फर्क
# Nearest to के: का उनके इसके मुबारक़ गुनदीपकुमार ब्रैंडेड लगाउसे अंतरिम
# Nearest to वह: जिसने हैउन्होंन वो वे एसेसमेंट अजमेरजिले सस्थापक मैं
# Nearest to भारत: बांह सेतिया डीटीसी तयकरने एनएसजी हैश्रम हैब्रिटिशपुलिस समाज
# Nearest to अपनी: उदारीकरण एसकेभट्टाचार्य पारा उनकी इंद्रेशकुमार खारिजकर रहेमहिला होगीडायबिटीज
# Nearest to ये: यह प्रदानकरने लैबोरेटरी हैंतभी वे घटा शासित काराकुल
# Nearest to करने: होने पूराकरने करके बनाने जोड़ने रखने लौहपुरुष किया
# Nearest to गए: गई जाने रहे जाते जन्में चुके रहें मकड़ी
# Average loss at step 72000: 0.516299
# Average loss at step 74000: 0.507140
# Average loss at step 76000: 0.503295
# Average loss at step 78000: 0.493876
# Average loss at step 80000: 0.490246
# Nearest to हुई: देंआपको पूरीतरहसे होती कियामुशर्रफ सौंपी करवाती होगी सेक्शन
# Nearest to न: तिरस्कार गएलूट चालू ऑनलाइन इंटरसेप्ट चाहिएकई कनफ्यूज थेहरेक
# Nearest to ज्यादा: अधिक कम रहेगाइसी ज़्यादा हैंब्रिटनी बची हलका डॉसेन
# Nearest to एक: यूनेस्को असहमति एफ घराने किसी श्रीलंकाई हालैंड हैएक
# Nearest to हुए: धारी बैठाना ध्रुव ऐस हुआ घोर बल्ब टाइकून
# Nearest to देने: भविष्ट आस्था पूराकरने मानने दिए दिया हैशायद वेश्याएँ
# Nearest to इस: हैइस चाहिएएनएसजी उस इसी एग्रीकल्चर कियानेचरन्यूरोसाइंस थाइस कामकरता
# Nearest to और: लेकिन जबकि दादाजी जोकि क्योंकि गोल्डमैनसैक्स सिरते कि
# Nearest to जब: मंगलवार रहस्यमय फार्मास्युटिकल बीएमडब्ल्यू जाएंरिज़र्वबैंकऑफ़इंडिया हैनया यूटिलाइजेशन चलाता
# Nearest to के: का उनके गुनदीपकुमार मुबारक़ इसके अंतरिम में लगाउसे
# Nearest to वह: वो मैं वे एसेसमेंट हैउन्होंन शांतिभूषण जिसने सस्थापक
# Nearest to भारत: सेतिया अरबडॉलर बांह ज़िले हैश्रम कियाफरवरी समाज होपटेल
# Nearest to अपनी: एसकेभट्टाचार्य पारा ड्राइवर उदारीकरण होगीडायबिटीज उनकी खारिजकर भेजेऐसी
# Nearest to ये: यह प्रदानकरने वे आवेशित रहेबढ़ती बोले इस कैलशियम
# Nearest to करने: होने पूराकरने बनाने करके रखने वैंगपाओ तैयारकरने लौहपुरुष
# Nearest to गए: गई जाने रहे जाते जन्में चुके जाएंगे कियाभारतीयों
# Average loss at step 82000: 0.484262
# Average loss at step 84000: 0.475723
# Average loss at step 86000: 0.476062
# Average loss at step 88000: 0.466442
# Average loss at step 90000: 0.460787
# Nearest to हुई: देंआपको सौंपी कियामुशर्रफ पूरीतरहसे होती गईमगर करवाती होगी
# Nearest to न: तिरस्कार ऑनलाइन रहेइन जेटलाइट संभाली वाशिंगटन नहीं राजनितिज्ञों
# Nearest to ज्यादा: अधिक कम ज़्यादा हैंब्रिटनी बची रहेगाइसी कॉलेस्ट्रॉल पोस्ट
# Nearest to एक: यूनेस्को इस एफ घराने असहमति ईडनगार्डन्स श्रीलंकाई ढहने
# Nearest to हुए: धारी बैठाना ऐस हुईकांग हुआ गेम्सविलेज सदीकउल्लाह बल्ब
# Nearest to देने: पूराकरने भविष्ट दिया आस्था हैशायद मानने शुरूकरने लेने
# Nearest to इस: हैइस चाहिएएनएसजी उस कामकरता एग्रीकल्चर इसी हैंइस कियानेचरन्यूरोसाइंस
# Nearest to और: लेकिन जबकि दादाजी क्योंकि गोल्डमैनसैक्स सिरते शाहअब्दुल्लाह एवं
# Nearest to जब: रहस्यमय मंगलवार बीएमडब्ल्यू जाएंरिज़र्वबैंकऑफ़इंडिया फार्मास्युटिकल पूर्णतया हैनया यूटिलाइजेशन
# Nearest to के: का उनके इसके गुनदीपकुमार लगाउसे मुबारक़ में करेगीइस
# Nearest to वह: हैउन्होंन मैं वो अजमेरजिले जिसने वे खातों थम
# Nearest to भारत: कियाफरवरी बांह सेतिया हैश्रम ज़िले सख्त अरबडॉलर होपटेल
# Nearest to अपनी: एसकेभट्टाचार्य उदारीकरण पारा ड्राइवर खारिजकर उनकी होगीडायबिटीज प्रचलित
# Nearest to ये: यह प्रदानकरने कैलशियम वे घटा लैबोरेटरी मशीनें हैंतभी
# Nearest to करने: होने पूराकरने बनाने करके रखने दबाने वैंगपाओ लौहपुरुष
# Nearest to गए: गई जाने जन्में जाते चुके रहे जाएंगे मकड़ी
# Average loss at step 92000: 0.460990
# Average loss at step 94000: 0.460013
# Average loss at step 96000: 0.453771
# Average loss at step 98000: 0.452829
# Average loss at step 100000: 0.447602
# Nearest to हुई: देंआपको कियामुशर्रफ सौंपी होगी होती करवाती गईमगर पूरीतरहसे
# Nearest to न: तिरस्कार नहीं चालू नहींदक्षिणअफ्रीका इंटरसेप्ट रहेइन वाशिंगटन ललितभनोट
# Nearest to ज्यादा: अधिक कम हैंब्रिटनी ज़्यादा रहेगाइसी बैक्टीरियल कॉलेस्ट्रॉल बची
# Nearest to एक: यूनेस्को असहमति एफ ढहने श्रीलंकाई घराने हैपेशावर किसी
# Nearest to हुए: धारी हुआ बैठाना घोर ध्रुव माडल गिरगांव वादक
# Nearest to देने: भविष्ट दिया पूराकरने आस्था मानने हैशायद लेने देते
# Nearest to इस: हैइस एग्रीकल्चर उस जहरीला इसी चाहिएएनएसजी थाइस इंडियन
# Nearest to और: जबकि लेकिन शाहअब्दुल्लाह जोकि दादाजी बनाईआज सिरते क्योंकि
# Nearest to जब: मंगलवार रहस्यमय बीएमडब्ल्यू हैनया फार्मास्युटिकल फर्क सिंधसरकार शुदा
# Nearest to के: का उनके क्रय गुनदीपकुमार को ब्रैंडेड हुईदोनों जाएगाउसके
# Nearest to वह: वो हैउन्होंन अजमेरजिले वे जिसने मैं थम बकायों
# Nearest to भारत: सेतिया कियाफरवरी बांह समाज तयकरने एनएसजी अरबडॉलर सख्त
# Nearest to अपनी: एसकेभट्टाचार्य उदारीकरण ड्राइवर खारिजकर उनकी बेड प्रचलित पारा
# Nearest to ये: यह हलका वे प्रदानकरने आवेशित मशीनें शासित हैंतभी
# Nearest to करने: होने बनाने पूराकरने करके लौहपुरुष रखने वैंगपाओ दबाने
# Nearest to गए: रहे जाने गई जाते जन्में चुके पूरेकर जाएंगे

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15, 15))
    for i, label in enumerate(labels):
        x, y = embeddings[i, :]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points', ha='right', va='bottom', fontproperties=hindi_font)
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %%
final_data = {
    'embeddings': final_embeddings,
    'dictionary': dictionary,
    'reverse_dictionary': reverse_dictionary
}

# %%
with open(os.path.join(root, 'embeddings_cbow.hi'), 'wb') as f:
    pickle.dump(file=f, obj=final_data)
